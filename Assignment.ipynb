# %% [markdown]
# Importing Required Library and reading csv file

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('SBIN_Data.csv')

# %%
df
# Out:
#             Date    Open    High     Low   Close  Volume      Time
# 0     01-01-2024  642.20  642.70  641.00  641.95   89481  09:15:00
# 1     01-01-2024  641.95  642.85  641.95  642.45   48965  09:16:00
# 2     01-01-2024  642.70  644.00  642.70  643.50   65729  09:17:00
# 3     01-01-2024  643.90  644.55  643.30  643.40   47909  09:18:00
# 4     01-01-2024  643.70  644.10  643.45  643.75   27645  09:19:00
# ...          ...     ...     ...     ...     ...     ...       ...
# 8245  31-01-2024  642.90  642.90  642.50  642.80  161605  15:25:00
# 8246  31-01-2024  642.90  642.95  642.50  642.90  143774  15:26:00
# 8247  31-01-2024  642.95  643.05  642.45  642.50  166278  15:27:00
# 8248  31-01-2024  642.50  642.65  641.40  641.70  138018  15:28:00
# 8249  31-01-2024  641.70  641.80  641.00  641.55   54342  15:29:00
#
# [8250 rows x 7 columns]

# %%
df.shape
# Out:
# (8250, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close         Volume
# count  8250.000000  8250.000000  8250.000000  8250.000000    8250.000000
# mean    630.800152   631.132764   630.458218   630.799848   44664.906061
# std      10.210328    10.170256    10.254218    10.210798   49381.392621
# min     601.400000   601.800000   600.650000   601.400000     821.000000
# 25%     623.900000   624.250000   623.500000   623.900000   16257.500000
# 50%     630.500000   630.900000   630.150000   630.500000   29342.000000
# 75%     639.950000   640.250000   639.650000   639.950000   54434.750000
# max     651.750000   651.750000   650.950000   651.750000  856782.000000

# %% [markdown]
# Creating a list to store working days and time.

# %%
l = [a for a in df["Date"].unique()]
l1 = [a for a in df["Time"].unique()]

# %%
vol = []

# %%
rank=[]

# %% [markdown]
# Now for every day on each minute, the volume is being compared to the last 5 days to find out the rank.

# %%
for i in l:
    for k in l1:
        volume = df[(df["Date"] == i) & (df['Time'] == k)]['Volume'].values[0]
        vol=[]
        for j in range(l.index(i), l.index(i)-6, -1):
            if j < 0:
                break
            vol.extend(df[(df["Date"] == l[j]) & (df['Time'] == k)]['Volume'].values)
        vol.sort(reverse=True)
        a = vol.index(volume)+1
        rank.append(a)

# %%
len(rank)
# Out:
# 8250

# %%
df['rank'] = rank

# %%
pd.options.display.max_rows = 10000

# %% [markdown]
# Rank is now added to the original DataFrame

# %%
df
# Out:
#             Date    Open    High     Low   Close  Volume      Time  rank
# 0     01-01-2024  642.20  642.70  641.00  641.95   89481  09:15:00     1
# 1     01-01-2024  641.95  642.85  641.95  642.45   48965  09:16:00     1
# 2     01-01-2024  642.70  644.00  642.70  643.50   65729  09:17:00     1
# 3     01-01-2024  643.90  644.55  643.30  643.40   47909  09:18:00     1
# 4     01-01-2024  643.70  644.10  643.45  643.75   27645  09:19:00     1
# 5     01-01-2024  643.75  644.00  643.20  643.45   39094  09:20:00     1
# 6     01-01-2024  643.30  643.95  643.30  643.60   11082  09:21:00     1
# 7     01-01-2024  643.60  643.95  643.20  643.40   22129  09:22:00     1
# 8     01-01-2024  643.35  643.90  643.30  643.55    9470  09:23:00     1
# 9     01-01-2024  643.55  645.70  643.55  645.50   91865  09:24:00     1
# 10    01-01-2024  645.55  645.65  644.50  645.00   37769  09:25:00     1
# 11    01-01-2024  644.65  644.95  644.25  644.40   18947  09:26:00     1
# ...

# %% [markdown]
# Plotting a graph of date 19-01-2024 for every minute where rank is 1

# %%
df1 = df[(df['Date']=='19-01-2024') & (df['rank'] == 1)]

# %%
plt.figure(figsize=(14,8),dpi=200)
plt.plot(df1['Time'], df1["Volume"])
plt.xticks(rotation=90);

# %% [markdown]
# On 19-01-2024 Peak Volume from last 5 days (rank 1) is at 11:06:00 and Lowest volume at 14:11:00 but still highest volume from last 5 days.
